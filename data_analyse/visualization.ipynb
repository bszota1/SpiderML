# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../build/training_stats.csv")
labels = df.columns

# %%
df.plot(x = df.columns[0], subplots=True, layout=(4,2))
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
